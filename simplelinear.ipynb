# %%
# understand the problem statement
# data collection

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\hp\Desktop\ds_MATERIAL\ML\regression_strm\placement.csv')

# %%
# df

# %%
plt.scatter(df['cgpa'],df['package'])

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
import seaborn as sns
# sns.boxplot(df['package'])

# %%
# !pip install scikit-learn
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df[['cgpa']],df[['package']],test_size=0.3,random_state=40)

# %%
# X_train

# %%
X_test.shape
# Out:
# (60, 1)

# %%
# model training
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#train acc
model.score(X_train,y_train)
# Out:
# 0.7783623334181906

# %%
# model.predict([[7.8]])

# %%
# model.predict([[6.89]])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,model.predict(X_train),color="red")

# %%
# X_train

# %%
# y_train

# %%
# model.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
# train acc
y_train_pred= model.predict(X_train)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.7783623334181906

# %%
#test acc
y_test_pred=model.predict(X_test)

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.7519705464243485

# %%
# print(dir(model))

# %%
# y=m*x+c

# %%
m=model.coef_
m
# Out:
# array([[0.57954434]])

# %%
c=model.intercept_
c
# Out:
# array([-1.02214643])

# %%
x=[[8.6]]

# %%
model.predict(x)
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.9619349]])

# %%
y=m*x+c
y
# Out:
# array([[3.9619349]])

# %%
# save file in binary
# pickle & joblib
#!pip install joblib
import joblib

# %%
#save the model
joblib.dump(model,"model.joblib")
# Out:
# ['model.joblib']

# %%
#load the model
model1=joblib.load("model.joblib")

# %%
model1.predict([[8.6]])
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.9619349]])

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\ps328\\ml'
